# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\Users\vamsi\Documents\Udemy\restart\Deep Learning\venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
###sentences
sent=['The glass of milk',
      'the glass of juice',
      'the cup of tea',
      'i am a good boy',
      'I am a good developer',
      'Understand the meaning of words',
      'your videos are good',]

# %%
sent
# Out:
# ['The glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'i am a good boy',
#  'I am a good developer',
#  'Understand the meaning of words',
#  'your videos are good']

# %%
##Define the vocabulary size
voc_size=10000

# %%
#One hot representation
one_hot_repr=[one_hot(words,voc_size) for words in sent]
one_hot_repr
# Out:
# [[3300, 8319, 74, 2090],
#  [3300, 8319, 74, 9856],
#  [3300, 7206, 74, 838],
#  [7287, 6723, 6775, 5880, 3791],
#  [7287, 6723, 6775, 5880, 1291],
#  [6252, 3300, 8324, 74, 7238],
#  [7457, 8675, 7853, 5880]]

# %%
##word embedding representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 3300 8319   74 2090]
#  [   0    0    0    0 3300 8319   74 9856]
#  [   0    0    0    0 3300 7206   74  838]
#  [   0    0    0 7287 6723 6775 5880 3791]
#  [   0    0    0 7287 6723 6775 5880 1291]
#  [   0    0    0 6252 3300 8324   74 7238]
#  [   0    0    0    0 7457 8675 7853 5880]]

# %%
##feature represntation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\Users\vamsi\Documents\Udemy\restart\Deep Learning\venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\vamsi\Documents\Udemy\restart\Deep Learning\venv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 188ms/step
# array([[[-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [ 0.04166492, -0.01158131, -0.03289529, -0.04936916,
#           0.00882947, -0.04331456, -0.03740624, -0.04058076,
#          -0.04500837, -0.0438576 ],
#         [-0.03303202,  0.04006486, -0.00288773,  0.02237907,
#           0.02074752, -0.02568263, -0.02806417,  0.00750069,
#           0.02635992,  0.01376916],
#         [ 0.04022067, -0.03811691, -0.01570047,  0.02163431,
#           0.0399544 ,  0.04036737,  0.04525818, -0.00152829,
#          -0.0277949 , -0.0214521 ],
#         [ 0.03987697,  0.01464764, -0.02864734,  0.04216721,
#           0.02228688,  0.03841057,  0.01945816, -0.00110456,
#          -0.03852331, -0.04321237]],
#
#        [[-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [ 0.04166492, -0.01158131, -0.03289529, -0.04936916,
#           0.00882947, -0.04331456, -0.03740624, -0.04058076,
#          -0.04500837, -0.0438576 ],
#         [-0.03303202,  0.04006486, -0.00288773,  0.02237907,
#           0.02074752, -0.02568263, -0.02806417,  0.00750069,
#           0.02635992,  0.01376916],
#         [ 0.04022067, -0.03811691, -0.01570047,  0.02163431,
#           0.0399544 ,  0.04036737,  0.04525818, -0.00152829,
#          -0.0277949 , -0.0214521 ],
#         [ 0.04727404,  0.00814415,  0.02089827, -0.00689393,
#          -0.01010617, -0.04083463,  0.00937594, -0.03603715,
#           0.03749218,  0.00806884]],
#
#        [[-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [ 0.04166492, -0.01158131, -0.03289529, -0.04936916,
#           0.00882947, -0.04331456, -0.03740624, -0.04058076,
#          -0.04500837, -0.0438576 ],
#         [-0.02226409, -0.00241338, -0.0038644 , -0.04708013,
#           0.02213664, -0.00737051, -0.01484532,  0.04262395,
#          -0.00087701, -0.0406485 ],
#         [ 0.04022067, -0.03811691, -0.01570047,  0.02163431,
#           0.0399544 ,  0.04036737,  0.04525818, -0.00152829,
#          -0.0277949 , -0.0214521 ],
#         [ 0.03439594, -0.02511001,  0.00847981, -0.01857094,
#          -0.00194903,  0.01933355,  0.0246391 ,  0.02339587,
#          -0.02472538,  0.04929363]],
#
#        [[-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [ 0.03537274,  0.04575062,  0.0360029 , -0.04729189,
#           0.00326774, -0.00690492,  0.03536505, -0.03568579,
#          -0.00457336, -0.04985467],
#         [-0.03865088, -0.0081957 , -0.03212181,  0.02874669,
#          -0.01547793, -0.03252702, -0.04575142,  0.02512546,
#          -0.00396588, -0.02047738],
#         [-0.04533546, -0.00608123, -0.02473742,  0.03102732,
#           0.01386347,  0.04151947, -0.02460371, -0.00747204,
#           0.04947419, -0.0063372 ],
#         [-0.00614906, -0.03382234,  0.00802945, -0.00858254,
#           0.00949711,  0.00873482, -0.00656997, -0.0138605 ,
#          -0.04185582,  0.04959066],
#         [-0.00984541,  0.04209142,  0.01584201,  0.01589649,
#           0.01959957, -0.02548925,  0.02769152,  0.00556502,
#           0.02797687,  0.0389799 ]],
#
#        [[-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [ 0.03537274,  0.04575062,  0.0360029 , -0.04729189,
#           0.00326774, -0.00690492,  0.03536505, -0.03568579,
#          -0.00457336, -0.04985467],
#         [-0.03865088, -0.0081957 , -0.03212181,  0.02874669,
#          -0.01547793, -0.03252702, -0.04575142,  0.02512546,
#          -0.00396588, -0.02047738],
#         [-0.04533546, -0.00608123, -0.02473742,  0.03102732,
#           0.01386347,  0.04151947, -0.02460371, -0.00747204,
#           0.04947419, -0.0063372 ],
#         [-0.00614906, -0.03382234,  0.00802945, -0.00858254,
#           0.00949711,  0.00873482, -0.00656997, -0.0138605 ,
#          -0.04185582,  0.04959066],
#         [-0.029074  , -0.04006114, -0.03133427, -0.01480546,
#           0.03324944, -0.04171829, -0.01152593,  0.0003971 ,
#          -0.01850697,  0.0010163 ]],
#
#        [[-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.04951613,  0.04043852, -0.03986124, -0.01016984,
#          -0.04254633,  0.01907473,  0.02801827,  0.02064467,
#           0.02832932, -0.01546174],
#         [ 0.04166492, -0.01158131, -0.03289529, -0.04936916,
#           0.00882947, -0.04331456, -0.03740624, -0.04058076,
#          -0.04500837, -0.0438576 ],
#         [ 0.00430974,  0.04541342, -0.03866237,  0.0416807 ,
#           0.04909365, -0.03392351, -0.00125407, -0.0266418 ,
#          -0.02541268,  0.00749589],
#         [ 0.04022067, -0.03811691, -0.01570047,  0.02163431,
#           0.0399544 ,  0.04036737,  0.04525818, -0.00152829,
#          -0.0277949 , -0.0214521 ],
#         [ 0.04932708, -0.04371368,  0.01197395, -0.04618363,
#          -0.0020848 ,  0.0422507 , -0.0159242 , -0.00099071,
#           0.01347898,  0.04437644]],
#
#        [[-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [-0.02681576,  0.03562012, -0.04742116,  0.0496862 ,
#           0.02830883, -0.01372367,  0.02182844, -0.01688766,
#          -0.04989642, -0.00968114],
#         [ 0.00720908,  0.00500865,  0.02229366, -0.02266758,
#           0.00279738, -0.04156645,  0.0446029 , -0.01780777,
#          -0.01731919,  0.04759795],
#         [-0.02836547,  0.003614  ,  0.04447133,  0.03804774,
#           0.0245477 ,  0.00157702, -0.03914102, -0.03340402,
#          -0.03578671, -0.03663033],
#         [ 0.00113666,  0.01759649,  0.04442256, -0.01527097,
#          -0.04637362,  0.03911697, -0.01330433, -0.02369102,
#           0.02355304,  0.00814001],
#         [-0.00614906, -0.03382234,  0.00802945, -0.00858254,
#           0.00949711,  0.00873482, -0.00656997, -0.0138605 ,
#          -0.04185582,  0.04959066]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 3300, 8319,   74, 2090])
